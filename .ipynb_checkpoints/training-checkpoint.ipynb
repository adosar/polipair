# %%
import numpy as np
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from joblib import dump

# %% [markdown]
# # Dataset

# %%
df = pd.read_csv('data/augmented_dataset.csv', index_col='id')

features = [i for i in df.columns if i != 'class']
target = 'class'

X, y = df.loc[:, features], df.loc[:, target]

# %%
df.head(5)
# Out:
#       ANDN920101  ARGP820101  ARGP820102  ARGP820103  BEGF750101  BEGF750102  \
# id
# 6cjp    4.404118    1.005294    1.486471    1.531176    0.700000    0.777059
# 3p5l    4.313000    0.828000    1.137000    1.127000    0.633000    0.851000
# 1utj    4.362727    0.625455    0.891818    0.800909    0.390909    0.679091
# 2zif    4.392500    1.061875    1.035000    1.114375    0.524375    0.740625
# 1qxl    4.428000    0.931333    1.318000    1.330667    0.643333    0.789333
#
#       BEGF750103  BHAR880101  BIGC670101  BIOV880101  ...      chi1n  \
# id                                                    ...
# 6cjp    0.663529    0.409471   84.794118   45.235294  ...  11.005714
# 3p5l    0.603000    0.400400   87.090000   53.000000  ...   5.625190
# 1utj    0.838182    0.457545   66.718182   24.909091  ...   2.764237
# 2zif    0.703750    0.436688   77.737500   20.500000  ...   8.482719
# 1qxl    0.738000    0.412667   84.586667   44.866667  ...  11.900591
#
#          chi2n     chi3n     chi4n  hallKierAlpha     kappa1     kappa2  \
# id
# 6cjp  5.526460  5.526460  3.745058          -3.78  23.380599  10.436197
# 3p5l  3.427906  3.427906  2.301945          -1.05  12.408054   5.071992
# 1utj  1.131500  1.131500  0.644677          -0.82   5.319276   2.478229
# 2zif  4.698579  4.698579  3.064262          -1.99  19.762817   7.941240
# 1qxl  6.209351  6.209351  4.225920          -3.91  24.222061  11.482918
#
#         kappa3       Phi  class
# id
# 6cjp  5.962061  7.176604      1
# 3p5l  2.456060  3.701974      1
# 1utj  1.073982  1.647798      1
# 2zif  3.987346  5.812639      1
# 1qxl  6.361879  7.946855      1
#
# [5 rows x 612 columns]

# %% [markdown]
# # Training

# %% [markdown]
# ## Configurations
#
# All the configurations have the form:
#
# $$ \text{scaler} \mapsto \text{reducer} \mapsto \text{classifier}$$

# %%
steps = [
    ('scaler', StandardScaler()),
    ('reducer', PCA(random_state=1)),
    ('classifier', 'passthrough'),  # Will be populated by param_grid.
]

param_grid = [
    {
        'reducer__n_components': [20, 50, 100, 300],
        'classifier': [RandomForestClassifier(random_state=1)],
        'classifier__n_estimators': [100, 200, 500],
        'classifier__min_samples_split': [2, 5, 10],
    },
    {
        'reducer__n_components': [20, 50, 100, 300],
        'classifier': [XGBClassifier(random_state=1)],
        'classifier__n_estimators': [50, 100, 500, 1000, 2000],
        'classifier__learning_rate': [0.1, 0.5, 1.],
        'classifier__max_depth': [2, 4, 6, 8],
    },
]

# %% [markdown]
# ## CV configuration

# %%
# Create the pipeline: scaler => reducer => classifier.
pipeline = Pipeline(steps=steps)

# Spli the data into train and test with stratification.
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True, stratify=y, train_size=0.9, random_state=1)

# 5-fold cross validation for tuning hyperparameters.
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=1)

# Use AUC as validation metric.
grid = GridSearchCV(estimator=pipeline, param_grid=param_grid, cv=kf, scoring='roc_auc', n_jobs=-1, refit=True)

# %% [markdown]
# ## Tuning hyperparameters and refitting on the whole training set

# %%
grid.fit(X_train, y_train)

# %% [markdown]
# # Save the best model and the grid

# %%
best_model = grid.best_estimator_
best_model

# %%
dump(best_model, 'saved_models/best_model.joblib')
dump(grid, 'saved_models/gridsearch_cv.joblib')
