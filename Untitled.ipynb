# %%
import pandas as pd

# %%
df = pd.read_csv('data/df_smiles_final.csv', index_col='Smiles 2')

# %%
df.head()
# Out:
#                                         Value     exactmw      amw  \
# Smiles 2
# O=C(c1n[nH]c(C(F)F)c1)Nc(ccc(F)c1)c1Cl    0.0  289.022974  289.644
# O=C(c1n[nH]nc1)Nc1ccccc1                  0.0  188.069811  188.190
# CC(C)C(Oc(cc1)c2cc1O)=CC2=O               0.0  204.078644  204.225
# CC(C)C(Oc1c2ccc(O)c1)=CC2=O               0.0  204.078644  204.225
# Clc1cc(-c2nc(ccc(Cl)c3)c3[o]2)n[nH]1      4.0  252.980967  254.076
#
#                                         lipinskiHBA  lipinskiHBD  \
# Smiles 2
# O=C(c1n[nH]c(C(F)F)c1)Nc(ccc(F)c1)c1Cl          4.0          2.0
# O=C(c1n[nH]nc1)Nc1ccccc1                        5.0          2.0
# CC(C)C(Oc(cc1)c2cc1O)=CC2=O                     3.0          1.0
# CC(C)C(Oc1c2ccc(O)c1)=CC2=O                     3.0          1.0
# Clc1cc(-c2nc(ccc(Cl)c3)c3[o]2)n[nH]1            4.0          1.0
#
#                                         NumRotatableBonds  NumHBD  NumHBA  \
# Smiles 2
# ...

# %%
new_df = pd.read_csv('data/Selected 15-LOX inhibitors_NE7.csv', index_col='smiles')

# %%
new_df.head()
# Out:
#                                                    Value
# smiles
# O=C(c(cc1)ccc1F)OCC#CCSc1nnc(-c2ccccc2)[o]1           26
# COc(cc1)ccc1-c1c(CCNS(N(CC2)CCN2c(cc2)cc(Cl)c2C...    36
# CCCCCCCCOC(NS(Nc(cc(cc1)-c2cc(cc(cc3)F)c3[nH]2)...    47
# Oc(cccc1)c1C(Nc1ccc(CCc(cc2)cc(O)c2O)cc1)=O          300
# CCCC(c1c(C(OCC)=O)[nH]c2c1ccc(Cl)c2)=O               730

# %%
df.loc['O=C(c(cc1)ccc1F)OCC#CCSc1nnc(-c2ccccc2)[o]1']
# Out:
# Value                               26.000000
# exactmw                            368.063091
# amw                                368.389000
# lipinskiHBA                          5.000000
# lipinskiHBD                          0.000000
# NumRotatableBonds                    5.000000
# NumHBD                               0.000000
# NumHBA                               6.000000
# NumHeavyAtoms                       26.000000
# NumAtoms                            39.000000
# NumHeteroatoms                       7.000000
# NumAmideBonds                        0.000000
# FractionCSP3                         0.105263
# NumRings                             3.000000
# NumAromaticRings                     3.000000
# NumAliphaticRings                    0.000000
# NumSaturatedRings                    0.000000
# NumHeterocycles                      1.000000
# NumAromaticHeterocycles              1.000000
# NumSaturatedHeterocycles             0.000000
# ...
